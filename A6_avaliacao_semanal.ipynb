# %% [markdown]
# # AS6 - AD - Previsão de Séries Temporais - Método Theta e Expansões

# %% [markdown]
# ### Questão 1:
#
# Considere a figura abaixo, identificada como Figura 4.1 em Pellegrini (2012). Nesse gráfico, são ilustradas a série temporal original não-sazonal e as linhas Theta com valores θ iguais a -1, -0.5 (modelo linear), 2.5 (alisamento exponencial simples) e 3. A previsão pelo método Theta em preto pontilhado é obtida combinando o modelo linear e alisamento exponencial simples.<br>
#
# ![ex1.png](attachment:ex1.png)
#
# Fonte: Pellegrini, T. R. (2012). Uma avaliação de métodos de previsão aplicados à grandes quantidades de séries temporais univariadas. Dissertação de mestrado. UFSCar.<br>
#
# Assinale a alternativa correta:<br>
#
# a.A previsão pelo Método Theta nesse caso pode ser não-linear.<br>
# b.A previsão obtida pelo Método Theta será sazonal.<br>
# c.A previsão obtida pelo Método Theta leva em consideração somente as últimas observações da série.<br>
# d.A previsão obtida pelo método Theta utiliza também as extrapolações dos modelos obtidos com θ iguais a -1 e 3.<br>
# <font color='red'>e.A previsão obtida pelo Método Theta está entre a linha de LRL e de AES.</font><br>

# %% [markdown]
# a-NOK - A previsão é linear.<br>
# b-NOK - Como a série original é não-sazonal, a previsão também será não sazonal.<br>
# e-OK - O método theta combina o modelo de regressão linear (theta=-0.5) com o modelo de suavização exponencial simples (theta=2.5)<br>

# %% [markdown]
# ### Questão 2:
#
# Considere o método Theta e as expansões apresentadas na Aula 6. Assinale a alternativa incorreta.<br>
#
# a.Com o método Theta, uma série temporal com sazonalidade é dessazonalizada, a previsão é obtida combinando as chamadas linhas Theta e a previsão é e então ressazonalizada para obter a previsão final.<br>
# b.O método Theta foi premiado na competição de forecasting M3.<br>
# <font color='red'>c.Os métodos Theta, Theta otimizado e Theta otimizado dinâmico exigem que a série temporal seja livre de tendência.</font><br>
# d.Assumir incorretamente que uma série não possui sazonalidade, quando na verdade possui, pode prejudicar as previsões obtidas pelo método Theta.<br>
# e.O método Theta pode ser usado para séries com sazonalidade e tendência.<br>

# %% [markdown]
# c-NOK O método Theta exige que a série temporal seja livre de sazonalidade. Caso haja, é necessário que seja dessazonalizada antes de aplicar o modelo.

# %% [markdown]
# ### Questão 3:
#
# Assinale todas as afirmações corretas.<br>
#
# a.O método Theta é equivalente ao método de média móvel simples.<br>
#
# <font color='red'>b.Os métodos Theta otimizado e Theta otimizado dinâmico são extensões do método Theta.</font><br>
#
# c.Ao utilizar a função ThetaModel do pacote statsmodels, se o usuário não informar se quer ou não dessazonalizar a série, assume-se que ela precisa ser dessazonalizada e as previsões terão sazonalidade.<br>
# ![ex3.png](attachment:ex3.png)
#
# <font color='red'>d.O método Theta otimizado fornece, além da previsão pontual, uma previsão intervalar para as próximas observações da série.</font><br>
#
# e.É necessário eliminar a tendência da série para aplicar os métodos Theta.<br>
#
# <font color='red'>f.O método Theta combina um modelo de regressão linear e alisamento exponencial simples para extrapolar a tendência da série dessazonalizada.</font><br>

# %% [markdown]
# a-NOK O método Theta é equivalente à média aritmética entre os modelos de regressão linear (theta=0) e o modelo exponencial simples(SES) que é equivalente ao método Holt (theta=2).<br>
#
# c-NOK Na condição default, só vai dessazonalizar se use_test nula for rejeitada.<br>
# deseasonalize : bool, default True<br>
# A flag indicating whether the deseasonalize the data. If True and use_test is True, the data is only deseasonalized if the null of no seasonal component is rejected.<br>
# use_test : bool, default True<br>
# A flag indicating whether test the period-th autocorrelation. If this test rejects using a size of 10%, then decomposition is used. Set to False to skip the test.
#
# d-OK com parâmetro .fit(use_mle=True).<br>
#
# e-NOK è necessário dessazonalizar.<br>

# %% [markdown]
# ### Questão 4:
#
# Considere o teste abaixo, discutido em Pellegrini (2012) no contexto de séries temporais, em que r significa a autocorrelação de lag indicado pelo seu sub-índice:<br>
# ![ex4.png](attachment:ex4.png)
#
# Assinale todas as afirmações corretas:<br>
#
# a.Se a desigualdade é falsa, há evidências de que há sazonalidade na série temporal.<br>
# <font color='red'>b.É possível utilizar a desigualdade acima para avaliar a sazonalidade de uma série temporal em um teste de hipóteses.</font><br>
# <font color='red'>c.Se os dados são diários e registrados em todos os dias úteis, o valor de m é 7.</font><br>
# d.A quantidade q é um quantil de uma distribuição qui-quadrado com 1-a/2 graus de liberdade.<br>

# %% [markdown]
# a-NOK Se a desigualdade é verdadeira, há uma sazonalidade.<br>
# b-OK<br>
# c-OK Apesar dos dados serem registrados apenas em dias úteis, eles são diários então m=7.<br>
# d-NOK q é o quantil da distribuição normal.<br>

# %% [markdown]
# ### Questão 5:
#
# Considere os pacotes de Python que utilizamos nesse curso até agora. Assinale a alternativa incorreta:<br>
#
# a.O pacote tensorflow_probability permite ajustes Bayesianos de séries temporais que tenham componentes de sazonalidade, tendência e termos autorregressivos, entre outros.<br>
#
# b.O pacote statsmodels permite ajustar modelos de séries temporais autorregressivos, de médias móveis, ARMA, ARIMA, SARIMA, além de modelos de espaço de estado com a inclusão de variáveis exógenas.<br>
#
# c.O pacote tensorflow permite o ajuste de modelos probabilísticos, incluindo o ajuste de modelos Bayesianos com simulação de Monte Carlos via Cadeias de Markov.<br>
#
# <font color='red'>d.O Método Theta é um método de forecasting que está implementado no pacote tensorflow_probability.</font><br>

# %% [markdown]
# d-NOK Método Theta está implementado no stasmodels.<br>
# from statsmodels.tsa.forecasting.theta import ThetaModel<br>
