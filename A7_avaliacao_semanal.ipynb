# %% [markdown]
# # AS7 - AD - Redes Dinâmicas

# %% [markdown]
# ### Questão 1:
#
# Sobre as redes neurais artificiais, assinale a alternativa **incorreta**:<br>
#
# a.As redes neurais artificiais têm inspiração em sistemas neurais biológicos<br>
# b.A indicação do caminho das informações nas redes neurais artificiais segue a orientação das setas nos grafos usados para representá-las<br>
# c.A função de ativação transforma a informação recebida e a leva para o próximo neurônio<br>
# <font color='red'>d.Na representação do perceptron, há sempre pelo menos três camadas ocultas, além de uma camada de entrada e uma de saída</font><br>

# %% [markdown]
# Perceptron = 1 neurônio artificial<br>
# Tem 1 camada de entrada, 1 de saída e Indefinidas camadas ocultas, no mínimo 1 onde ocorre a transformação.<br>

# %% [markdown]
# ### Questão 2:
#
# Sobre redes neurais recorrentes, assinale as alternativas **corretas**:<br>
#
# <font color='red'>a.As redes neurais recorrentes servem para modelar dados que são coletados de forma sequencial</font><br>
#
# b.O diagrama abaixo representa a modelagem de redes neurais artificiais para dados independentes ao longo do tempo<br>
#
# ![Captura%20de%20tela%202021-08-28%20072342.png](attachment:Captura%20de%20tela%202021-08-28%20072342.png)
#
#
# c.As redes neurais recorrentes armazenam toda a informação recebida em sua memória<br>
#
# <font color='red'>d.Long Short-Term Memory (LSTM) e GRU (Gated Recurrent Unit) são exemplos de redes neurais artificiais recorrentes</font><br>

# %% [markdown]
# c-NOK RNN armazenam alguma ou nenhuma informação em sua memória.

# %% [markdown]
# ### Questão 3:
#
# Sobre o Long Short-Term Memory (LSTM) e GRU (Gated Recurrent Unit), assinale a alternativa **incorreta**:<br>
#
# ![Captura%20de%20tela%202021-08-28%20072548.png](attachment:Captura%20de%20tela%202021-08-28%20072548.png)
#
# <font color='red'>a.Nos dois métodos há seleção de informações que serão armazenadas ou descartadas no processo</font><br>
#
# b.Um só neurônio pode representar informações de vetores de dados<br>
#
# c.GRU é uma simplificação do LSTM<br>
#
# d.Tanto o LSTM quanto o GRU podem ser usados para fazer modelagem de séries temporais<br>

# %% [markdown]
# O GRU é uma simplificação do LSTM, e a diferença é que no GRU não há porta de esquecimento (forget gate).

# %% [markdown]
# ### Questão 4:
#
# Sobre a modelagem de redes neurais recorrentes, assinale a alternativa **incorreta**:<br>
#
# a.A implementação de RNNs pode ser feita no keras, que é uma interface de programação de aplicativos (API) do tensorflow<br>
#
# b.Para a implementação do LSTM usa-se uma camada do tipo Dense para representar a camada de saída da rede neural artificial<br>
#
# c.É necessário definir uma função de perda e um otimizador para desenvolver o modelo de redes neurais artificiais<br>
#
# <font color='red'>d.Um único neurônio em geral é suficiente para fazer a modelagem de dados complexos com estrutura sequencial como dados de séries temporais</font><br>

# %% [markdown]
# d-NOK São necessárias em geral várias camadas e vários neurônios para a modelagem de dados complexos com estrutura sequencial.
