# %% [markdown]
# # AS5 - AD - MODELOS DE ESPAÇO DE ESTADO

# %% [markdown]
# ### Questão 1:
#
# Considere a representação gráfica do modelo oculto de Markov (fonte: Wikipedia). Com base nesse diagrama, selecione a alternativa incorreta.<br>
#
# ![q1.png](attachment:q1.png)
#
# Escolha uma opção:<br>
#
# <font color='red'>a.O modelo oculto de Markov pode ser usado para modelar um problema de séries temporais como um modelo estrutural em que a série observada nos tempos t=1,2,3 é X1, X2 e X3.</font><br>
#
# b.As quantidades bij, com i=1,2,3 e j=1,2,3,4, representam as probabilidades de saída do espaço escondido para o espaço observável.<br>
#
# c.X1, X2 e X3 representam as variáveis no estado oculto ou hidden space e as y1, y2, y3 e y4 as variáveis observáveis.<br>
#
# d.y1, y2, y3 e y4 representam as variáveis observáveis do modelo.<br>
#
# e.O valor da variável X3 depende exclusivamente do valor da variável X2.<br>
#
# f.O comportamento das variáveis no espaço observável depende exclusivamente do comportamento das variáveis no espaço oculto.<br>

# %% [markdown]
# ### Questão 2:
#
# Considere um modelo AR(2) descrito pela equação<br>
# ![q2.1.png](attachment:q2.1.png)

# %% [markdown]
# e que pode ser reescrito como um modelo de espaço de estado na forma<br>
# ![q2.2.png](attachment:q2.2.png)

# %% [markdown]
# Assinale a alternativa correta
#
# Escolha uma opção:
#
# a.A matriz de transição é dada por
# ![q2a.png](attachment:q2a.png)

# %% [markdown]
# b.A matriz de seleção é dada por ![q2b.png](attachment:q2b.png)

# %% [markdown]
# c.O modelo de espaço de estado não poderia ser usado para descrever outros processos como ARIMA ou SARIMA.<br>
#
# d.Neste modelo foi incluída uma variável exógena, X.<br>
#
# <font color='red'>e.Os três parâmetros que devem ser estimados são</font> ![q2e.png](attachment:q2e.png)

# %% [markdown]
# ### Questão 3:
#
# Um modelo Bayesiano foi ajustado aos dados de CO2. Assinale todas as alternativas corretas sobre esse modelo
# ![q3.png](attachment:q3.png)
#
# Escolha uma ou mais:<br>
#
# a.Para ajustar um modelo Bayesiano, é estritamente necessário ter informações a priori sobre os parâmetros do modelo, tal como conhecer seus hiperparâmetros<br>
#
# b.Existe uma tendência claramente não-linear de crescimento na média de concentração de CO2 ao longo dos anos<br>
#
# <font color='red'>c.A região laranja representa uma previsão intervalar e esse intervalo aumenta conforme o modelo se distancia da amostra de treino, dada a maior incerteza sobre o futuro mais distante</font><br>
#
# <font color='red'>d.A previsão pontual neste modelo tende a subestimar a concentração de CO2</font><br>

# %% [markdown]
# Para ajustar um modelo Bayesiano, não é ESTRITAMENTE necessário ter informações a priori sobre os parâmetros do modelo, tal como conhecer seus hiperparâmetros

# %% [markdown]
# ### Questão 4:
#
# Sobre os modelos de espaço de estado para a representação de séries temporais, assinale a alternativa incorreta<br>
#
# Escolha uma opção:<br>
#
# <font color='red'>a.Os ruídos precisam necessariamente ter distribuição normal</font><br>
#
# b.Em modelos estruturais as equações são denominadas equação de medida e equação de transição<br>
#
# c.Uma variável exógena é uma variável externa adicionada ao modelo e representa uma outra série temporal com influência na variabilidade da série temporal principal de estudo<br>
#
# d.No enfoque clássico, em geral é obtido o estimador de máxima verossimilhança mas os estimadores dificilmente podem ser encontrados de forma explícita<br>
#
# e.A previsão dinâmica em modelos de espaço de estado possui mais fontes de variabilidade do que a previsão passo à frente<br>
#
# f.No contexto Bayesiano, muitos estimadores são baseados em medidas resumo a partir de amostras da distribuição a posteriori dos parâmetros<br>
#
# g.O filtro de Kalman é um algoritmo recursivo que determina a estimativa do vetor de estados no tempo t dada toda a informação disponı́vel até o instante t-1<br>

# %% [markdown]
# a-nok<br>
# b-ok<br>
# c-ok<br>
# d-ok<br>
# e-ok<br>
# f-ok<br>
# g-ok<br>
#
# a-Os ruídos são modelados como se tivessem distribuição normal, essa é a hipótese do modelo, mas não necessariamente têm distribuição normal.<br>
# O ruído pode se referir tanto ao erro do modelo quanto à série temporal a ser modelada.<br>
# O termo ruído se refere: (1) à série temporal a ser modelada usando um modelo de espaço de estado ou (2) aos resíduos existentes nas equações de medida e transição $\varepsilon_t$ e $\eta_t$<br>
#
# g-A modelagem bayesiana assume que os parâmetros desse modelo seguem distribuições de probabilidade (distribuições a priori) e, a partir da distribuição conjunta dos parâmetros e dados, obtém estimativas a partir da distribuição a posteriori dos parâmetros dadas as observações.
