# %% [markdown]
# # AS1 - AD - Séries Temporais

# %% [markdown]
# ### Questão 1:
#
# Assinale o item que não corresponde a um objetivo de análise de séries temporais:<br>
#
# Escolha uma opção:<br>
# a. Fazer previsões de valores futuros da série com base em comportamentos passados, a menos de possíveis incertezas de predição<br>
# <font color='red'>b. Identificar dados extremos que possam ser eliminados da série de observações</font><br>
# c. Descrever comportamentos como tendência ou sazonalidade em dados coletados ao longo do tempo<br>
# d. Compreender e modelar a correlação entre medidas sequenciais de uma certa variável observada repetidamente em um longo período de tempo<br>
# e. Compreender como duas séries temporais diferentes estão associadas, e possivelmente utilizar as variações de uma para explicar as variações de outra<br>

# %% [markdown]
# ### Questão 2:
#
# Assinale todos os exemplos típicos de séries temporais:<br>
#
# Escolha uma ou mais:<br>
# a. Medidas de pressão arterial em 30 indivíduos, antes e após utilizar um certo medicamento para controle de hipertensão<br>
# b. Notas de redação obtidas por todos os alunos do estado de São Paulo no ENEM em 2020<br>
# <font color='red'>c. Quantidades mensais de mortes por pneumonia em uma cidade europeia por dez anos</font><br>
# <font color='red'>d. Medidas diárias de glicemia de jejum por uma gestante com diabetes gestacional, nos últimos três meses de gestação</font><br>
# <font color='red'>e. Índices diários de fechamento das ações MGLU3 na Bolsa de Valores de SP por seis meses</font><br>

# %% [markdown]
# ### Questão 3:
#
# Considere as seguintes séries temporais e identifique as três em que o comportamento sazonal é mais claro:<br>
#
# Escolha uma opção:<br>
# <font color='red'>a. I, II e V</font><br>
# b. II, III e IV<br>
# c. I, III e V<br>
# d. II, III e V<br>
# e. II, IV e V<br>

# %% [markdown]
# ![Q3_fig1.png](attachment:Q3_fig1.png)

# %% [markdown]
# ![Q3_fig2.png](attachment:Q3_fig2.png)

# %% [markdown]
# ![Q3_fig3.png](attachment:Q3_fig3.png)

# %% [markdown]
# ![Q3_fig4.png](attachment:Q3_fig4.png)

# %% [markdown]
# ![Q3_fig5.png](attachment:Q3_fig5.png)

# %% [markdown]
# ### Questão 4:
#
# No gráfico a seguir, assinale as cores das séries: original, média móvel com janela r=5 e média móvel com janela r=15, respectivamente<br>
#
# Escolha uma opção:<br>
# a. laranja, azul e verde<br>
# b. azul, verde e laranja<br>
# <font color='red'>c. azul, laranja e verde</font><br>
# d. verde, azul e laranja<br>
# e. laranja, verde e azul<br>
#
# ![Q4.png](attachment:Q4.png)

# %% [markdown]
# ### Questão 5:
#
# Sobre suavização e alisamento exponencial, assinale todas as alternativas corretas:<br>
#
# Escolha uma ou mais:<br>
# <font color='red'>a. A cada novo instante de tempo, a média móvel simples com janela r é calculada como a média aritmética das últimas r observações da série em estudo</font><br>
# <font color='red'>b. A média móvel exponencialmente ponderada dá pesos maiores a observações mais recentes e menores a observações mais distantes</font><br>
# c. As técnicas de média móvel simples, mediana móvel simples e média móvel exponencialmente ponderadas auxiliam na previsão da sazonalidade da série temporal<br>
# <font color='red'>d. A curva da série da mediana móvel simples é menos suave do que a da média móvel simples</font><br>
# <font color='red'>e. A média móvel simples costuma não atingir picos e vales e produz curvas mais suaves conforme r aumenta</font><br>
# <font color='red'>f. A média móvel exponencialmente ponderada é menos afetada por pontos anteriores extremos do que a média móvel simples</font><br>

# %% [markdown]
# Questão 5f apresenta interpretação dúbia e será anulada
