# %% [markdown]
# # AS8 - AD - Análise de Sobrevivência

# %% [markdown]
# ### Questão 1:
#
# Sobre estudos de análise de sobrevivência, assinale as alternativas **corretas**<br>
#
# <font color='red'>a.O estimador de Kaplan Meier é o estimador de máxima verossimilhança da função de sobrevivência S(t).</font><br>
# <font color='red'>b.O estimador de Kaplan Meier é um estimador não-paramétrico.</font><br>
# c.Hazard ratio e risco relativo são sinônimos.<br>
# d.Em análise de sobrevivência, é necessário observar o tempo de vida até que o evento de interesse aconteça para todos os indivíduos em estudo.<br>

# %% [markdown]
# c.NOK Hazard ratios (HR) differ from relative risks (RRs) and odds ratios (ORs) in that RRs and ORs are cumulative over an entire study, using a defined endpoint, while HRs represent instantaneous risk over the study time period, or some subset thereof. Hazard ratios suffer somewhat less from selection bias with respect to the endpoints chosen and can indicate risks that happen before the endpoint. https://en.wikipedia.org/wiki/Hazard_ratio  <br>
#
# De uma forma simplificada, o hazard ratio (ou razão de riscos) é uma razão das funções de risco, como menciono no início do vídeo 4, quando falo do Modelo de Cox.<br>
#
# Já o risco relativo (relative risk) é uma razão de duas probabilidades, de um certo evento ocorrer em um grupo onde uma certa característica está presente e do mesmo evento ocorrer em um grupo onde a característica não está presente. <br>
#
# Vamos pensar em um exemplo em que o evento de interesse é o cancelamento de um cartão de crédito por clientes que recebem o seu salário ou não pelo banco que forneceu o cartão (presença ou não da característica).  Você pode observar os clientes por 5 anos e verificar ao final quantos cancelaram em cada grupo, e comparar os riscos com o risco relativo. Mas se você utilizar a razão de riscos (hazard ratio) isso representa uma razão dos riscos em um certo instante ou período.<br>
#
# Como menciono no vídeo 2 (aprox. 8:45), a função de risco se refere a um risco instantâneo e portanto a razão de riscos é uma medida calculada em um período ou instante específico. Já o risco relativo leva em consideração todo o período de estudo.<br>
#
# Se quiser se aprofundar, recomendo os materiais mencionados na Aula 8 e para um acesso mais rápido os seguintes links<br>
# https://pt.wikipedia.org/wiki/Raz%C3%A3o_de_risco  <br>
# https://en.wikipedia.org/wiki/Relative_risk  <br>
#
# d.NOK Em muitos exemplos não espera-se até que o evento aconteça.<br>
# Ocorre quando os dados são censurados ou mesmo pode ocorrer a situação de que o evento nunca ocorrerá (fração de cura).<br>

# %% [markdown]
# ### Questão 2:
#
# Considere um estudo em que o interesse é predizer o evento contágio por coronavírus em habitantes de uma cidade, a partir do primeiro dia de 2021. Para isso, foi coletada uma amostra de tamanho 1000 e os indivíduos sorteados foram acompanhados por 5 meses, com testes de sorologia que detectam a presença de anticorpos de coronavírus. Os voluntários são acompanhados até que o seu primeiro teste positivo seja observado. O interesse do estudo é avaliar o tempo até o contágio pelo coronavírus.  Assinale as alternativas **corretas**:<br>
#
# <font color='red'>a.Alguns voluntários saíram do estudo e os anticorpos ainda não haviam sido observados. Esses dados são censurados à direita.</font><br>
# <font color='red'>b.Se o primeiro teste em um voluntário apontou a presença de anticorpos, esse dado é censurado à esquerda.</font><br>
# <font color='red'>c.Um voluntário fez dois testes. O primeiro teste, há dois meses, deu resultado negativo e o segundo teste há um mês deu resultado positivo. Esse dado possui censura intervalar.</font><br>
# d.Esse tipo de estudo leva em consideração a possibilidade de o mesmo voluntário se contaminar duas vezes com o mesmo vírus.<br>
# e.Para estudar esses dados utilizando técnicas de análise de sobrevivência é estritamente necessário supor que todos os voluntários irão em algum momento se contaminar com o coronavírus.<br>

# %% [markdown]
# **Censura à Direita**: Tempo de sobrevida maior que o tempo observado  𝑇≥𝑂  (mais comum) <br>
# **Censura à Esquerda**: Follow up até pessoas serem contaminadas por coronavírus  𝑇≤𝑂  <br>
# Fez teste em  𝑡  e deu positivo então sei que  𝑇<𝑡 .<br>
# **Censura Intervalar**: Só sei que  𝑡1≤𝑇≤𝑡2 : Fiz testes nos instantes t1 e t2. <br>

# %% [markdown]
# ### Questão 3:
#
# Assinale a alternativa **incorreta** sobre a classificação de tipos de censura.<br>
#
# a.Quando um número preestabelecido de eventos ocorrem, as outras observações sofrem **censura tipo II**.<br>
# b.A **censura tipo I** ocorre quando um tempo é preestabelecido para o fim das observações, e então os pacientes em que não se observou o evento de interesse têm suas observações censuradas.<br>
# c.A **censura aleatória** é observada quando além dos tempos de vida, as censuras também ocorrem em tempos aleatórios.<br>
# <font color='red'>d.Quando um paciente não apresenta bons resultados à medicação e é retirado do estudo, ocorre uma **censura independente**.</font><br>

# %% [markdown]
# a-OK Censura tipo II refere-se a censura de número de eventos.<br>
# b-OK Censura tipo I tem o tempo de observação censurado.<br>
# c-OK Pega-se o mínimo de (T,C), ou seja, o que acontecer primeiro.<br>
# d-NOK A censura nesse caso não é independente do mecanismo que provoca a morte.<br>

# %% [markdown]
# 𝑟: número de falhas ou eventos
#
# **Censura Aleatória**: Tempo de falha  (𝑇)  e de censura  (𝐶)  aleatórios e observamos  𝑡=𝑚𝑖𝑛(𝑇,𝐶) .
# **Censura tipo I**: Estudo acaba após certo tempo e temos  𝑟  falhas e no final do estudo temos  𝑛−𝑟  censuras.
# **Censura tipo II**:  𝑟  é fixado e só os menores  𝑟  tempos são observados e todos os outros tempos são censurados. O maior tempo observado é t(r).
# **Censura Independente**: ocorrência dessa censura é independente do mecanismo que provoca a morte. E se a pessoa com melhor prognóstico sempre larga o estudo?

# %% [markdown]
# ### Questão 4:
#
# Sobre estudos de análise de sobrevivência, assinale as alternativas **corretas**:<br>
#
# <font color='red'>a.O estimador de Kaplan-Meier na figura abaixo pode indicar um modelo de longa duração, ou seja, o evento de interesse pode nunca ocorrer para parte da amostra </font><br>
# ![Captura%20de%20tela%202021-09-07%20201137.png](attachment:Captura%20de%20tela%202021-09-07%20201137.png)

# %% [markdown]
# <font color='red'>b.Na figura abaixo, a probabilidade de um indivíduo sobreviver pelo menos até o tempo 45 é aproximadamente 60% </font> <br>
# ![Captura%20de%20tela%202021-09-07%20201228.png](attachment:Captura%20de%20tela%202021-09-07%20201228.png)

# %% [markdown]
# c.Na figura abaixo, as linhas azuis representam dados que foram censurados pois naquelas observações o evento de interesse não ocorreu até o tempo t=12 <br>
# ![Captura%20de%20tela%202021-09-07%20200356.png](attachment:Captura%20de%20tela%202021-09-07%20200356.png)

# %% [markdown]
# c. estaria correta se mencionasse t=10 e não t=12

# %% [markdown]
# <font color='red'>d.O estimador de Kaplan-Meier na Figura abaixo dá evidências de maior probabilidade de sobrevida no grupo controle do que no grupo miR-137 </font><br>
#
# ![Captura%20de%20tela%202021-09-07%20200633.png](attachment:Captura%20de%20tela%202021-09-07%20200633.png)

# %% [markdown]
# <font color='red'>e.Considerando o modelo de Cox abaixo, a maior razão de riscos está relacionada à variável 1 e a menor à variável 2 </font> <br>
#
# ![Captura%20de%20tela%202021-09-07%20201327.png](attachment:Captura%20de%20tela%202021-09-07%20201327.png)

# %% [markdown]
# var1: Risco Relativo é **8% maior** que o Risco de Base (sem a presença do fator)<br>
# var2: Risco Relativo é igual ao Risco de Base (sem a presença do fator) pois p-valor > 0.05, ou seja, não é significativa para o modelo.<br>
# var3: Risco Relativo é **7% maior** que o Risco de Base (sem a presença do fator)<br>
