# %% [markdown]
# # Prática 7
#
# Aprendizado Dinâmico
#
# por Cibele Russo (ICMC/USP - São Carlos SP)
#
# MBA em Ciências de Dados

# %% [markdown]
# Nesta prática vamos considerar redes dinâmicas para modelar a temperatura global dos dados em globaltemp.

# %% [markdown]
# **1.Faça a leitura das bibliotecas.**

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# **2. Leia os dados do arquivo globaltemp.csv.**

# %%
# Temperatura global

# Diferenças na média de temperatura global. 
# Fonte: https://github.com/mjuez/pytsdatasets/

pkgdir = 'dados'
# pkgdir = '/hdd/MBA/AprendizadoDinamico/Data'


df = pd.read_csv(f'{pkgdir}/globaltemp.csv', index_col=0,
                         parse_dates=True)
df.index = df.index
df.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.head()
# Out:
#             data
# year
# 1880-01-01 -0.20
# 1881-01-01 -0.11
# 1882-01-01 -0.10
# 1883-01-01 -0.20
# 1884-01-01 -0.28

# %% [markdown]
# ##

# %% [markdown]
# **3.  Divida a base em treino e teste, deixando 14 dias para a previsão.**

# %%
len(df)
# Out:
# 136

# %%
len(df)-14
# Out:
# 122

# %%
train = df.iloc[:122]
test = df.iloc[122:]

# %%
train
# Out:
#             data
# year
# 1880-01-01 -0.20
# 1881-01-01 -0.11
# 1882-01-01 -0.10
# 1883-01-01 -0.20
# 1884-01-01 -0.28
# ...          ...
# 1997-01-01  0.48
# 1998-01-01  0.63
# 1999-01-01  0.42
# 2000-01-01  0.42
# 2001-01-01  0.55
#
# [122 rows x 1 columns]

# %% [markdown]
# **4. Padronize os dados para a modelagem.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
print(scaled_train.min(),scaled_train.max())
# Out:
# 0.0 1.0

# %%
print(scaled_test.min(),scaled_test.max())
# Out:
# 0.9181818181818182 1.2181818181818183

# %%
plt.hist(scaled_train);

# %% [markdown]
# **5. Considere o gerador de séries temporais, com variados valores para os parâmetros length e batch_size.**

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# defina o gerador
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
len(scaled_train)
# Out:
# 122

# %%
len(generator) # n_input = 2
# Out:
# 120

# %%
# Qual é a aparência do primeiro lote?
X,y = generator[0]

# %%
print(f'Dado o array: \n{X.flatten()}');
print(f'Previsão: \n {y}');
# Out:
# Dado o array:
# [0.24545455 0.32727273]
# Previsão:
#  [[0.33636364]]

# %% [markdown]
# **6. Carregue as bibliotecas do keras para as redes dinâmicas.**

# %%
### Pacote ideal do tensorflow = 2.5
### Pacote ideal do keras = 2.6
### Caso necessário, instale o pacote nessas versões

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# **7. Defina os lotes para o processo iterativo.**

# %%
# Vamos redefinir lotes de tamanho 21 para o procedimento iterativo
# Veja mais informações sobre o tamanho do lote http://deeplearningbook.com.br/o-efeito-do-batch-size-no-treinamento-de-redes-neurais-artificiais/

n_input = 21
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %% [markdown]
# **8. Defina o modelo. Ele pode ter uma camada LSTM e uma camada Dense. Teste alternativas.**

# %%
# Defina o modelo
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **9. Faça o ajuste do modelo e observe a função de perda.**

# %%
# Ajuste do modelo

model.fit_generator(generator,epochs=100)
# Out:
# C:\Users\joaop\anaconda3\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 101/101 [==============================] - 3s 5ms/step - loss: 0.0307
# Epoch 2/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0144
# Epoch 3/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0143
# Epoch 4/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0124
# Epoch 5/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0135
# Epoch 6/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0122
# Epoch 7/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0109
# Epoch 8/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0116
# Epoch 9/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0116
# Epoch 10/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0109
# Epoch 11/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0134
# Epoch 12/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0112
# Epoch 13/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0115
# Epoch 14/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0112
# Epoch 15/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0110
# Epoch 16/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 17/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0102
# Epoch 18/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0109
# Epoch 19/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0100
# Epoch 20/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0120
# Epoch 21/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0113
# Epoch 22/100
# 101/101 [==============================] - 1s 13ms/step - loss: 0.0099
# Epoch 23/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0103
# Epoch 24/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0092
# Epoch 25/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0100
# Epoch 26/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0103
# Epoch 27/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0111
# Epoch 28/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0101
# Epoch 29/100
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0103
# Epoch 30/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0099
# Epoch 31/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0100
# Epoch 32/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0103
# Epoch 33/100
# 101/101 [==============================] - 0s 4ms/step - loss: 0.0102
# Epoch 34/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0104
# Epoch 35/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0105
# Epoch 36/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0099
# Epoch 37/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0097
# Epoch 38/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0094
# Epoch 39/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0106
# Epoch 40/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0104
# Epoch 41/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0095
# Epoch 42/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0106
# Epoch 43/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0095
# Epoch 44/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0092
# Epoch 45/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0100
# Epoch 46/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0097
# Epoch 47/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0097
# Epoch 48/100
# 101/101 [==============================] - 2s 15ms/step - loss: 0.0097: 1s
# Epoch 49/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0096
# Epoch 50/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0096
# Epoch 51/100
# 101/101 [==============================] - 1s 6ms/step - loss: 0.0092
# Epoch 52/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0096
# Epoch 53/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0096
# Epoch 54/100
# 101/101 [==============================] - 2s 24ms/step - loss: 0.0097
# Epoch 55/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0099
# Epoch 56/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0097
# Epoch 57/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0094
# Epoch 58/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0101
# Epoch 59/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 60/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0095A: 0s - l
# Epoch 61/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0099
# Epoch 62/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0097
# Epoch 63/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0095
# Epoch 64/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0098
# Epoch 65/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0103
# Epoch 66/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0092
# Epoch 67/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0098
# Epoch 68/100
# 101/101 [==============================] - 2s 15ms/step - loss: 0.0095
# Epoch 69/100
# 101/101 [==============================] - 1s 9ms/step - loss: 0.0100
# Epoch 70/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0095
# Epoch 71/100
# 101/101 [==============================] - 3s 27ms/step - loss: 0.0101
# Epoch 72/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0095
# Epoch 73/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0093
# Epoch 74/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0096
# Epoch 75/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0093
# Epoch 76/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0093
# Epoch 77/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0095
# Epoch 78/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0098
# Epoch 79/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0094
# Epoch 80/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 81/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0096
# Epoch 82/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0090
# Epoch 83/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 84/100
# 101/101 [==============================] - 2s 15ms/step - loss: 0.0097
# Epoch 85/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0098
# Epoch 86/100
# 101/101 [==============================] - 1s 8ms/step - loss: 0.0092
# Epoch 87/100
# 101/101 [==============================] - 1s 9ms/step - loss: 0.0093
# Epoch 88/100
# 101/101 [==============================] - 2s 22ms/step - loss: 0.0086
# Epoch 89/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0088
# Epoch 90/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0099
# Epoch 91/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0093
# Epoch 92/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0095
# Epoch 93/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0092
# Epoch 94/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0094
# Epoch 95/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0090
# Epoch 96/100
# 101/101 [==============================] - 1s 7ms/step - loss: 0.0091
# Epoch 97/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0090
# Epoch 98/100
# 101/101 [==============================] - 1s 5ms/step - loss: 0.0096
# Epoch 99/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 100/100
# 101/101 [==============================] - 0s 5ms/step - loss: 0.0089

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %% [markdown]
# **10. Faça a previsão.**

# %%
# Vejamos passo a passo como é feita a previsão, a princípio para a próxima observação usando o tamanho do lote igual a 7

first_eval_batch = scaled_train[-7:]

# %%
first_eval_batch
# Out:
# array([[0.84545455],
#        [0.73636364],
#        [0.86363636],
#        [1.        ],
#        [0.80909091],
#        [0.80909091],
#        [0.92727273]])

# %%
# Agora vamos considerar as previsões para as próximas 21 observações e comparar com a base de teste

test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # obter a previsão de tempo 1 antecipadamente ([0] é para pegar apenas o número em vez de [array])
    current_pred = model.predict(current_batch)[0]
    
    # predição
    test_predictions.append(current_pred) 
    
    # atualize a rodada para agora incluir a previsão e descartar o primeiro valor
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.90530974], dtype=float32),
#  array([0.89926445], dtype=float32),
#  array([0.92265475], dtype=float32),
#  array([0.9330025], dtype=float32),
#  array([0.9490323], dtype=float32),
#  array([0.9635382], dtype=float32),
#  array([0.9793462], dtype=float32),
#  array([0.9951857], dtype=float32),
#  array([1.0112818], dtype=float32),
#  array([1.0286183], dtype=float32),
#  array([1.0460285], dtype=float32),
#  array([1.064448], dtype=float32),
#  array([1.0836302], dtype=float32),
#  array([1.1042522], dtype=float32)]

# %%
scaled_test
# Out:
# array([[1.        ],
#        [0.99090909],
#        [0.92727273],
#        [1.05454545],
#        [1.        ],
#        [1.02727273],
#        [0.91818182],
#        [1.00909091],
#        [1.08181818],
#        [0.97272727],
#        [1.        ],
#        [1.02727273],
#        [1.10909091],
#        [1.21818182]])

# %% [markdown]
# **11. Retorne da padronização.**

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[0.52584071],
#        [0.5191909 ],
#        [0.54492022],
#        [0.55630272],
#        [0.57393554],
#        [0.58989205],
#        [0.60728084],
#        [0.62470424],
#        [0.64241003],
#        [0.66148017],
#        [0.68063134],
#        [0.7008928 ],
#        [0.72199322],
#        [0.74467744]])

# %%
# Possivelmente encontraremos warnings aqui
test['Predictions'] = true_predictions
# Out:
# <ipython-input-40-b5be589fc0d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %% [markdown]
# **12. Visualize os resultados, comparando as previsões com a base de teste.**

# %%
test.plot();

# %%
ax = train.plot()
test.plot(ax=ax);
