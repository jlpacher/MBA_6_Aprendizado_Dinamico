# %% [markdown]
# # AS4 - AD - Modelos ARIMA, SARIMA. Diagnóstico.

# %% [markdown]
# ### Questão 1:
#
# ![q1.png](attachment:q1.png)
#
# Escolha uma opção:<br>
# <font color='red'>a. SARIMA(0,1,1)x(0,1,0)12, ARIMA(1,1,0), SARIMA(1,0,1)x(0,1,0)7, ARIMA(0,1,1)</font><br>
# b. SARIMA(0,2,1)x(1,1,0)12, ARIMA(1,1,0), SARIMA(1,1,1)x(0,1,0)7, ARMA(1,1)<br>
# c. ARIMA(0,1,1), ARIMA(0,1,1), SARIMA(1,0,1)x(7), ARMA(0,1)<br>
# d. ARIMA(1,1,1), ARIMA(0,1,1), SARIMA(1,0,1)x(0,1,0)7, ARMA(1,1)<br>
# e. SARIMA(0,1,1)x(0,1,0)12, ARIMA(0,1,1), ARIMA(1,0,1), ARIMA(0,1,1)<br>

# %% [markdown]
# SARIMA(p,d,q)(P,D,Q)m <br>
#
# I) p=P=0; d=1; m=12; D=1; q=1; Q=0       ===> SARIMA(0,1,1)(0,1,0)12 <br>
# II) p=1; d=1; D=0; m=0; q=0              ===> SARIMA(1,1,0)(0,0,0)0 == ARIMA(1,1,0) <br>
# III) p=1; P=0; m=7; d=0; D=1; q=1; Q=0   ===> SARIMA(1,0,1)(0,1,0)7 <br>
# IV) p=P=0; d=1; D=0; m=0; q=1; Q=0       ===> SARIMA(0,1,1)(0,0,0)0 == ARIMA(0,1,1) <br>

# %% [markdown]
# SARIMA
#
# $\phi(B) \Phi(B^m ) W_t = \theta(B) \Theta(B^m ) a_ t$
#
# onde
#
# - $\phi(B) = (1-\alpha_1 B-\ldots \alpha_p B^p)$
#
# - $\Phi(B^m)= (1- \phi_1 B^m-\ldots - \phi_p B^{P_m})$
#
# - $W_t = \Delta^d \Delta^D Z_t = (1-B)^d (1-B^m)^D Z_t$
#
# - $\theta(B) = (1+\beta_1 B + \ldots + \beta_q B^q)$
#
# - $\Theta(B^m) = (1+\theta_1 B^m+\ldots+\theta_Q B^{Q_m})$

# %% [markdown]
# ### Questão 2:
#
# Sobre modelos ARIMA e SARIMA, assinale todas as alternativas corretas<br>
#
# Escolha uma ou mais:<br>
# a. Um modelo SARIMA (0,1,0)x(2,0,0)7 possui componentes autorregressivas com sazonalidade de período 7 e de média móvel sem sazonalidade<br>
# b. Os critérios AIC e BIC garantem que o modelo escolhido é o correto<br>
# <font color='red'>c. Os modelos ARIMA e SARIMA são adequados para séries não-estacionárias mas cujas diferenças de alguma ordem, simples ou com sazonalidade, sejam estacionárias</font><br>
# <font color='red'>d. Nos modelos SARIMA é possível incluir componentes autorregressivas, integradas e de médias móveis com ou sem sazonalidade</font><br>
# <font color='red'>e. Um modelo SARIMA (1,0,0)x(1,1,0)7 possui componentes autorregressivas simples e com sazonalidade de período 7</font><br>
# <font color='red'>f. Os resíduos de um modelo ajustado não devem apresentar padrões nos gráficos de autocorrelação, mas caso apresentem, podem auxiliar na busca por um modelo mais adequado</font><br>
# <font color='red'>g. Os modelos ARIMA são casos particulares dos modelos SARIMA quando não se tem sazonalidade nas componentes autorregressiva, integrada ou de médias móveis</font><br>

# %% [markdown]
# ### Questão 3:
#
# Os gráficos dos itens foram obtidos a partir de resíduos de modelos ajustados do tipo SARIMA. Assinale as alternativas em que há evidências claras de que o modelo NÃO está bem ajustado.<br>
#
# Escolha uma ou mais:<br>
# <font color='red'>a. </font><br>
# b. <br>
# c. <br>
# <font color='red'>d. </font><br>
# <font color='red'>e. </font><br>
#
# ![q3a.png](attachment:q3a.png)

# %% [markdown]
# Para indicar normalidade o gráfico dos quartis deveria ser uma reta.

# %% [markdown]
# ![q3b.png](attachment:q3b.png)

# %% [markdown]
# ![q3c.png](attachment:q3c.png)

# %% [markdown]
# ![q3d.png](attachment:q3d.png)

# %% [markdown]
# Para indicar normalidade os resíduos não devem ter correlação nenhuma (exceto o primeiro ponto que representa correlação com ele mesmo).

# %% [markdown]
# ![q3e.png](attachment:q3e.png)

# %% [markdown]
# Para indicar normalidade o histograma dos resíduos deveriam indicar uma curva normal.

# %% [markdown]
# ### Questão 4:
#
# Considere os comandos abaixo. Assinale a alternativa incorreta<br>
#
# Escolha uma opção:<br>
# a. seasonal=True permite o ajuste de um modelo do tipo SARIMA (p,d,q)x(P,D,Q)m com período de sazonalidade m=12.<br>
# b. Como stepwise=True, o comando resultará a lista de modelos ajustados com o AIC correspondente.<br>
# <font color='red'>c. A ordem das componentes autorregressivas não-sazonal e sazonal estarão entre 0 e 3, já que start_p=0 e max_p=3.</font><br>
# <font color='red'>d. O modelo resultante terá, necessariamente, termos autorregressivo, integrado e de médias móveis com sazonalidade, mesmo se a série vem de um processo somente com componentes não-sazonais.</font><br>
# <font color='red'>e. A ordem das componentes de médias móveis não-sazonal e sazonal serão no máximo 3, já que max_q=3.</font><br>
#
# ![q4.png](attachment:q4.png)

# %% [markdown]
# Questão anulada.<br>
# max_P, max_Q, max_D (parte sazonal) fornecem os máximos para P, Q e D.<br>
# Quando não declarados assumem os valores default 2, 2 e 1.<br>
# https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html

# %% [markdown]
# ### Questão 5:
#
# O seguinte resultado foi obtido para os casos confirmados de COVID-19 no estado de SP. Assinale a alternativa incorreta.<br>
#
# Escolha uma opção:<br>
# a. O melhor modelo ajustado contém componentes de médias móveis não sazonal e sazonal, ambas de ordem 1.<br>
# b. Os intervalos de confiança apontam para a significância estatística das componentes de médias móveis não sazonal, autorregressiva sazonal, médias móveis sazonal em testes individuais.<br>
# c. O melhor modelo ajustado foi o SARIMA(0,1,1)x(1,0,1)7.<br>
# <font color='red'>d. O melhor modelo ajustado contém componente autorregressiva não-sazonal de ordem 1.</font><br>
# e. O melhor modelo escolhido contém uma componente integrada de ordem 1 não-sazonal.<br>
#
# ![q5.png](attachment:q5.png)
