# %% [markdown]
# # AS2 - AD - Métodos de Suavização. Estacionariedade.

# %% [markdown]
# ### Questão 1:
#
# Assinale a alternativa incorreta a respeito dos métodos de suavização<br>
#
# Escolha uma opção:<br><br>
# a. O método de Holt-Winters supõe que a série temporal possui componentes de tendência e de sazonalidade e pode produzir previsões para as observações futuras.<br>
# b. O método de Holt supõe que a série temporal possui uma componente de tendência mas não de sazonalidade, porém pode produzir previsões para as próximas observações.<br>
# <font color='red'>c. Existem três tipos de sazonalidade, a aditiva, a multiplicativa e a exponencial.</font><br>
# d. Os métodos de Holt e Holt-Winters permitem fazer previsões para as observações futuras, porém, se a sazonalidade estiver presente, o método de Holt-Winters produzirá previsões mais acuradas.<br>
# e. A média móvel simples e a média móvel exponencialmente ponderada são técnicas descritivas e portanto não são recomendadas para fazer previsão.<br>

# %% [markdown]
# As sazonalidades podem ser do tipo aditiva ou multiplicativa.

# %% [markdown]
# ### Questão 2:
#
# Assinale uma ou mais alternativas corretas para descrever o método utilizado na figura abaixo para os dados de passageiros aéreos vistos em aula<br>
#
# Escolha uma ou mais:<br>
# a. Os dados de passageiros aéreos apresentados na figura possuem sazonalidade semanal, dada a dinâmica de vôos em dias úteis e aos finais de semana.<br>
# <font color='red'>b. Suponha, hipoteticamente, que os dados continuaram a ser observados até os dias atuais, e que o padrão de tendência e sazonalidade tivessem continuado até 2019. Se o método fosse treinado com os dados até 2019, as previsões para o ano de 2020 estariam possivelmente comprometidas, devido à queda do número de vôos durante a pandemia de COVID-19.</font><br>
# <font color='red'>c. A sazonalidade foi considerada pelo método para produzir previsões das futuras observações.</font><br>
# d. A curva em laranja não representa dados reais da base original de passageiros aéreos.<br>
# <font color='red'>e. A base de treinamento possui cerca de 75% das observações e a base de teste 25% das observações da base original de dados.</font><br>
# f. É possível afirmar que as bases de treinamento e teste para o método de Holt-Winters têm cada uma 50% das observações.<br>
#
# ![Q2.png](attachment:Q2.png)

# %% [markdown]
# ### Questão 3:
#
# Considere as primeiras e segundas diferenças a seguir, e assinale uma ou mais alternativas corretas sobre elas.<br>
#
#
#
# Escolha uma ou mais:<br>
# <font color='red'>a. Não é garantido que a primeira ou a segunda diferenças produzem uma série estacionária.</font><br>
# b. A série da primeira diferença elimina o efeito de sazonalidade da série original.<br>
# <font color='red'>c. É possível que a tendência da série temporal seja eliminada ao considerar a primeira diferença dos dados.</font><br>
# <font color='red'>d. A primeira e segunda diferenças são também séries temporais, porém a primeira diferença possui uma observação a menos que a série original, e uma observação a mais do que a série das segundas diferenças.</font><br>
# <font color='red'>e. Para muitas séries temporais, a primeira diferença produz uma série estacionária ou tendência-estacionária.</font><br>

# %% [markdown]
# ![Q3.png](attachment:Q3.png)

# %% [markdown]
# ### Questão 4:
#
# Sobre a estacionariedade de séries temporais, assinale a alternativa incorreta.<br>
#
# Escolha uma opção:<br>
# a. Considere os boxplots abaixo para as mortes registradas por COVID-19 no estado de São Paulo, que apontam para a não-estacionariedade da série. Nas semanas 19 e 20, pode ter havido falha no registro de mortes, o que pode justificar a presença dos pontos que se destacam como atípicos (outliers). É possível também que os outliers tenham surgido naturalmente por causa da distribuição do fenômeno estudado.<br>
#
# ![Q4a.png](attachment:Q4a.png)

# %% [markdown]
# <font color='red'>b. A série das ações VALE3 na figura abaixo não apresenta padrão de estacionariedade em nenhuma possível janela de observação no último ano.</font><br>
# ![Q4b.png](attachment:Q4b.png)

# %% [markdown]
# c. Os diagramas de caixa (boxplots) ao longo do tempo podem indicar uma mudança na média da série e portanto a sua não-estacionariedade.<br>
# ![Q4c.png](attachment:Q4c.png)

# %% [markdown]
# d. A média e o desvio-padrão móveis representados em laranja e em verde, respectivamente, podem auxiliar de forma descritiva para a verificação da estacionariedade da série temporal original (em azul).<br>
# ![Q4d.png](attachment:Q4d.png)

# %% [markdown]
# ### Questão 5:
#
# Considere o teste de Dickey e Fuller, ou Dickey e Fuller aumentado. Assinale uma ou mais alternativas corretas.<br>
#
# Escolha uma ou mais:<br>
# <font color='red'>a. É possível obter um valor-p baixo e a série temporal não ser estacionária mas ser apenas tendência-estacionária, ou seja, que não apresenta tendência positiva ou negativa ao longo do tempo.</font><br>
# <font color='red'>b. Quando o valor p obtido está próximo de 0.9, há evidências da não-estacionariedade da série temporal.</font><br>
# c. Os testes dão garantia de estacionariedade quando, para uma determinada série temporal, o valor p é 0.04.<br>
# <font color='red'>d. Os testes fornecem evidências a favor ou contra a estacionariedade.</font><br>
